# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# I chose a freestyle project that predicts whether a content page is likely to experience growth, recovery, stability, or decline during a future time window using historical search and engagement signals. This problem is useful because websites often contain thousands of pages, making it difficult for content teams to decide which pages should be updated first. A prediction model can help prioritize review efforts by identifying pages that may improve or deteriorate, allowing teams to allocate their time more efficiently.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# Can historical search and engagement signals be used to predict whether a content page is likely to experience growth, recovery, stability, or decline over a future time period?

# The model supports the decision of which content pages should be reviewed or updated first.

# SEO specialists, content managers, or website administrators use the ranked recommendations.

# If the model recommends the wrong pages, the team may spend time improving pages that would have performed well without intervention while overlooking pages that actually needed attention. This mainly results in reduced efficiency and missed optimization opportunities.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
from datasets import load_dataset
import pandas as pd

ds = load_dataset(
    "FlyRank/internship-warehouse",
    "dim_content",
    split="train"
)

df = ds.to_pandas()

print(f"Number of content pages: {len(df):,}")
print(f"Number of features (columns): {len(df.columns)}")

print("\nMissing values per column:")
print(df.isna().sum().sort_values(ascending=False).head(10))

print("\nFirst 10 columns:")
print(df.columns.tolist()[:10])
# Out:
# Number of content pages: 519,606
# Number of features (columns): 26
#
# Missing values per column:
# optimization_eligible_date    474210
# last_optimized_date           474210
# provider_used                 369936
# backlinks                     267474
# word_count                    177768
# char_count                    177768
# main_intent                   148398
# competition_level             144456
# cpc                           142622
# search_volume                 142622
# dtype: int64
#
# First 10 columns:
# ['client_hash_id', 'content_hash_id', 'keyword_hash_id', 'url_hash_id', 'keyword_char_count', 'keyword_token_count', 'url_char_count', 'content_created_date', 'content_updated_date', 'content_type']

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This project measures whether historical search and engagement signals are associated with future page performance categories. The resulting model is intended as a decision-support tool that ranks pages according to their estimated likelihood of growth, recovery, stability, or decline. Model performance will be evaluated using held-out data and standard machine learning metrics.
# This project does not prove that any feature causes page growth or decline. It does not predict Google's ranking algorithm or guarantee future search performance. The model only estimates patterns that were observed in the available historical data and may not generalize to every website or future condition.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
